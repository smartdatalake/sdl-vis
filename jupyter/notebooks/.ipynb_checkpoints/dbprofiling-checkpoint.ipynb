# %%
#import pandas as pd
#import psycopg2
import sqlalchemy

# %run helpers.py

# %%
#connection details
dbtoken = {
    'address': 'localhost',
    'port': '15432',
    'user': 'postgres',
    'pass': 'smartdatalake',
    'dbname': 'sample_db'
}
postgres_str = f'postgresql://{dbtoken["user"]}:{dbtoken["pass"]}@{dbtoken["address"]}:{dbtoken["port"]}/{dbtoken["dbname"]}'

cnx = sqlalchemy.create_engine(postgres_str)

# %%
con = cnx.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2284         try:
# -> 2285             return fn()
#    2286         except dialect.dbapi.Error as e:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     656             with util.safe_reraise():
# --> 657                 pool.logger.debug("Error on connect(): %s", e)
#     658         else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     489         # inherits the docstring from interfaces.Dialect.connect
# --> 490         return self.dbapi.connect(*cargs, **cparams)
#     491
#
# /opt/conda/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 15432?
# could not connect to server: Cannot assign requested address
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 15432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-141d7d2bcecb> in <module>
# ----> 1 con = cnx.connect()
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2216         """
#    2217
# -> 2218         return self._connection_cls(self, **kwargs)
#    2219
#    2220     @util.deprecated(
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2316         """
#    2317         return self._wrap_pool_connect(
# -> 2318             self.pool.unique_connection, _connection
#    2319         )
#    2320
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2287             if connection is None:
#    2288                 Connection._handle_dbapi_exception_noconnection(
# -> 2289                     e, dialect, self
#    2290                 )
#    2291             else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1553         elif should_wrap:
#    1554             util.raise_(
# -> 1555                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1556             )
#    1557         else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2283         dialect = self.dialect
#    2284         try:
# -> 2285             return fn()
#    2286         except dialect.dbapi.Error as e:
#    2287             if connection is None:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     301
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#     305     def _create_connection(self):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     771     def _checkout(cls, pool, threadconns=None, fairy=None):
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#     775             fairy._pool = pool
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     655         except Exception as e:
#     656             with util.safe_reraise():
# --> 657                 pool.logger.debug("Error on connect(): %s", e)
#     658         else:
#     659             if first_connect_check:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     650         try:
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#     654             self.connection = connection
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     488     def connect(self, *cargs, **cparams):
#     489         # inherits the docstring from interfaces.Dialect.connect
# --> 490         return self.dbapi.connect(*cargs, **cparams)
#     491
#     492     def create_connect_args(self, url):
#
# /opt/conda/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 15432?
# could not connect to server: Cannot assign requested address
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 15432?
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
#get the tablenames
names = con.execute('''SELECT tablename FROM pg_catalog.pg_tables WHERE schemaname='public';''')
tbname = []
for row in names:
    tbname.append(row['tablename'])

# %%
for table in tbname:
    #table = 'rental'

    #get column information
    cols = con.execute(f'''SELECT column_name, data_type FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = '{table}';''')

    column = []
    for column_n in cols:
        column.append({'name': column_n["column_name"], 'dtype': column_n["data_type"]})    

    
    display(HTML(f"<h1>{table}</h1>"))

    for col in column:
        #col = 'return_date'

        #create a row
        rowentry(table, col, con)
# Out:
# <h1>actor</h1>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 actor_id
#             </div>
#             <div>
#                 integer
#             </div>
#         </span> <span style='width:60%'><?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (https://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 54 252
# L 388.8 252
# L 388.8 34.56
# L 54 34.56
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p5500bbaf4b)" d="M 69.218182 252
# L 79.363636 252
# L 79.363636 44.914286
# L 69.218182 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p5500bbaf4b)" d="M 79.363636 252
# L 89.509091 252
# L 89.509091 44.914286
# L 79.363636 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#p5500bbaf4b)" d="M 89.509091 252
# L 99.654545 252
# L 99.654545 74.497959
# L 89.509091 74.497959
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path clip-path="url(#p5500bbaf4b)" d="M 99.654545 252
# L 109.8 252
# L 109.8 44.914286
# L 99.654545 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_7">
#     <path clip-path="url(#p5500bbaf4b)" d="M 109.8 252
# L 119.945455 252
# L 119.945455 44.914286
# L 109.8 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_8">
#     <path clip-path="url(#p5500bbaf4b)" d="M 119.945455 252
# L 130.090909 252
# L 130.090909 74.497959
# L 119.945455 74.497959
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_9">
#     <path clip-path="url(#p5500bbaf4b)" d="M 130.090909 252
# L 140.236364 252
# L 140.236364 44.914286
# L 130.090909 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_10">
#     <path clip-path="url(#p5500bbaf4b)" d="M 140.236364 252
# L 150.381818 252
# L 150.381818 44.914286
# L 140.236364 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_11">
#     <path clip-path="url(#p5500bbaf4b)" d="M 150.381818 252
# L 160.527273 252
# L 160.527273 74.497959
# L 150.381818 74.497959
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_12">
#     <path clip-path="url(#p5500bbaf4b)" d="M 160.527273 252
# L 170.672727 252
# L 170.672727 44.914286
# L 160.527273 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 first_name
#             </div>
#             <div>
#                 character varying
#             </div>
#         </span> <span style="width:60%"><table style="width:100%"><tr><td style="text-align:right">Julia</td><td style="text-align:left">2.0%</td></tr><tr><td style="text-align:right">Kenneth</td><td style="text-align:left">2.0%</td></tr><tr><td style="text-align:right">Penelope</td><td style="text-align:left">2.0%</td></tr><tr><td style="text-align:right">Cameron</td><td style="text-align:left">1.5%</td></tr><tr><td style="text-align:right">Christian</td><td style="text-align:left">1.5%</td></tr></table></span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">128</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">200</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr></table> </span></div>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 last_name
#             </div>
#             <div>
#                 character varying
#             </div>
#         </span> <span style="width:60%"><table style="width:100%"><tr><td style="text-align:right">Kilmer</td><td style="text-align:left">2.5%</td></tr><tr><td style="text-align:right">Temple</td><td style="text-align:left">2.0%</td></tr><tr><td style="text-align:right">Nolte</td><td style="text-align:left">2.0%</td></tr><tr><td style="text-align:right">Harris</td><td style="text-align:left">1.5%</td></tr><tr><td style="text-align:right">Zellweger</td><td style="text-align:left">1.5%</td></tr></table></span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">121</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">200</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr></table> </span></div>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 last_update
#             </div>
#             <div>
#                 timestamp without time zone
#             </div>
#         </span> <span style='width:60%;text-align:center'>2013-05-26 14:47:57.620000</span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">1</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">200</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">mean</td>
#                     <td style="text-align:left">2013-05-26 14:47:57.619997</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">min</td>
#                     <td style="text-align:left">2013-05-26 14:47:57.620000</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">max</td>
#                     <td style="text-align:left">2013-05-26 14:47:57.620000</td>
#                 </tr></table> </span></div>
# <h1>store</h1>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 store_id
#             </div>
#             <div>
#                 integer
#             </div>
#         </span> <span style='width:60%'><?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (https://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 221.4 44.443636
# C 195.19702 44.443636 170.040442 54.863832 151.512137 73.392137
# C 132.983832 91.920442 122.563636 117.07702 122.563636 143.28
# C 122.563636 169.48298 132.983832 194.639558 151.512137 213.167863
# C 170.040442 231.696168 195.19702 242.116364 221.4 242.116364
# L 221.4 143.28
# L 221.4 44.443636
# z
# " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 221.4 242.116364
# C 247.60298 242.116364 272.759558 231.696168 291.287863 213.167863
# C 309.816168 194.639558 320.236364 169.48298 320.236364 143.28
# C 320.236364 117.07702 309.816168 91.920442 291.287863 73.392137
# C 272.759558 54.863832 247.60298 44.443636 221.4 44.443636
# L 221.4 143.28
# L 221.4 242.116364
# z
# " style="fill:#ff7f0e;"/>
#    </g>
#    <g id="matplotlib.axis_1"/>
#    <g id="matplotlib.axis_2"/>
#    <g id="text_1">
#     <!-- 1 -->
#     <defs>
#      <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-49"/>
#     </defs>
#     <g transform="translate(108.8625 144.935625)scale(0.06 -0.06)">
#      <use xlink:href="#DejaVuSans-49"/>
#     </g>
#    </g>
#    <g id="text_2">
#     <!-- 2 -->
#     <defs>
#      <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-50"/>
#     </defs>
#     <g transform="translate(330.12 144.935625)scale(0.06 -0.06)">
#      <use xlink:href="#DejaVuSans-50"/>
#     </g>
#    </g>
#   </g>
#  </g>
# </svg>
# </span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">2</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">2</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">mean</td>
#                     <td style="text-align:left">1.5000000000000000</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">min</td>
#                     <td style="text-align:left">1</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">max</td>
#                     <td style="text-align:left">2</td>
#                 </tr></table> </span></div>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 manager_staff_id
#             </div>
#             <div>
#                 smallint
#             </div>
#         </span> <span style='width:60%'><?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (https://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 221.4 44.443636
# C 195.19702 44.443636 170.040442 54.863832 151.512137 73.392137
# C 132.983832 91.920442 122.563636 117.07702 122.563636 143.28
# C 122.563636 169.48298 132.983832 194.639558 151.512137 213.167863
# C 170.040442 231.696168 195.19702 242.116364 221.4 242.116364
# L 221.4 143.28
# L 221.4 44.443636
# z
# " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 221.4 242.116364
# C 247.60298 242.116364 272.759558 231.696168 291.287863 213.167863
# C 309.816168 194.639558 320.236364 169.48298 320.236364 143.28
# C 320.236364 117.07702 309.816168 91.920442 291.287863 73.392137
# C 272.759558 54.863832 247.60298 44.443636 221.4 44.443636
# L 221.4 143.28
# L 221.4 242.116364
# z
# " style="fill:#ff7f0e;"/>
#    </g>
#    <g id="matplotlib.axis_1"/>
#    <g id="matplotlib.axis_2"/>
#    <g id="text_1">
#     <!-- 1 -->
#     <defs>
#      <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-49"/>
#     </defs>
#     <g transform="translate(108.8625 144.935625)scale(0.06 -0.06)">
#      <use xlink:href="#DejaVuSans-49"/>
#     </g>
#    </g>
#    <g id="text_2">
#     <!-- 2 -->
#     <defs>
#      <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-50"/>
#     </defs>
#     <g transform="translate(330.12 144.935625)scale(0.06 -0.06)">
#      <use xlink:href="#DejaVuSans-50"/>
#     </g>
#    </g>
#   </g>
#  </g>
# </svg>
# </span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">2</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">2</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">mean</td>
#                     <td style="text-align:left">1.5000000000000000</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">min</td>
#                     <td style="text-align:left">1</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">max</td>
#                     <td style="text-align:left">2</td>
#                 </tr></table> </span></div>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 address_id
#             </div>
#             <div>
#                 smallint
#             </div>
#         </span> <span style='width:60%'><?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (https://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 221.4 44.443636
# C 195.19702 44.443636 170.040442 54.863832 151.512137 73.392137
# C 132.983832 91.920442 122.563636 117.07702 122.563636 143.28
# C 122.563636 169.48298 132.983832 194.639558 151.512137 213.167863
# C 170.040442 231.696168 195.19702 242.116364 221.4 242.116364
# L 221.4 143.28
# L 221.4 44.443636
# z
# " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 221.4 242.116364
# C 247.60298 242.116364 272.759558 231.696168 291.287863 213.167863
# C 309.816168 194.639558 320.236364 169.48298 320.236364 143.28
# C 320.236364 117.07702 309.816168 91.920442 291.287863 73.392137
# C 272.759558 54.863832 247.60298 44.443636 221.4 44.443636
# L 221.4 143.28
# L 221.4 242.116364
# z
# " style="fill:#ff7f0e;"/>
#    </g>
#    <g id="matplotlib.axis_1"/>
#    <g id="matplotlib.axis_2"/>
#    <g id="text_1">
#     <!-- 1 -->
#     <defs>
#      <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-49"/>
#     </defs>
#     <g transform="translate(108.8625 144.935625)scale(0.06 -0.06)">
#      <use xlink:href="#DejaVuSans-49"/>
#     </g>
#    </g>
#    <g id="text_2">
#     <!-- 2 -->
#     <defs>
#      <path d="M 19.1875 8.296875
# L 53.609375 8.296875
# L 53.609375 0
# L 7.328125 0
# L 7.328125 8.296875
# Q 12.9375 14.109375 22.625 23.890625
# Q 32.328125 33.6875 34.8125 36.53125
# Q 39.546875 41.84375 41.421875 45.53125
# Q 43.3125 49.21875 43.3125 52.78125
# Q 43.3125 58.59375 39.234375 62.25
# Q 35.15625 65.921875 28.609375 65.921875
# Q 23.96875 65.921875 18.8125 64.3125
# Q 13.671875 62.703125 7.8125 59.421875
# L 7.8125 69.390625
# Q 13.765625 71.78125 18.9375 73
# Q 24.125 74.21875 28.421875 74.21875
# Q 39.75 74.21875 46.484375 68.546875
# Q 53.21875 62.890625 53.21875 53.421875
# Q 53.21875 48.921875 51.53125 44.890625
# Q 49.859375 40.875 45.40625 35.40625
# Q 44.1875 33.984375 37.640625 27.21875
# Q 31.109375 20.453125 19.1875 8.296875
# z
# " id="DejaVuSans-50"/>
#     </defs>
#     <g transform="translate(330.12 144.935625)scale(0.06 -0.06)">
#      <use xlink:href="#DejaVuSans-50"/>
#     </g>
#    </g>
#   </g>
#  </g>
# </svg>
# </span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">2</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">2</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">mean</td>
#                     <td style="text-align:left">1.5000000000000000</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">min</td>
#                     <td style="text-align:left">1</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">max</td>
#                     <td style="text-align:left">2</td>
#                 </tr></table> </span></div>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 last_update
#             </div>
#             <div>
#                 timestamp without time zone
#             </div>
#         </span> <span style='width:60%;text-align:center'>2006-02-15 09:57:12</span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">1</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">2</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">mean</td>
#                     <td style="text-align:left">2006-02-15 09:57:12</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">min</td>
#                     <td style="text-align:left">2006-02-15 09:57:12</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">max</td>
#                     <td style="text-align:left">2006-02-15 09:57:12</td>
#                 </tr></table> </span></div>
# <h1>address</h1>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 address_id
#             </div>
#             <div>
#                 integer
#             </div>
#         </span> <span style='width:60%'><?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (https://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 54 252
# L 388.8 252
# L 388.8 34.56
# L 54 34.56
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p4788fc0f1b)" d="M 69.218182 252
# L 79.363636 252
# L 79.363636 44.914286
# L 69.218182 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p4788fc0f1b)" d="M 79.363636 252
# L 89.509091 252
# L 89.509091 54.77551
# L 79.363636 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#p4788fc0f1b)" d="M 89.509091 252
# L 99.654545 252
# L 99.654545 54.77551
# L 89.509091 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path clip-path="url(#p4788fc0f1b)" d="M 99.654545 252
# L 109.8 252
# L 109.8 54.77551
# L 99.654545 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_7">
#     <path clip-path="url(#p4788fc0f1b)" d="M 109.8 252
# L 119.945455 252
# L 119.945455 54.77551
# L 109.8 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_8">
#     <path clip-path="url(#p4788fc0f1b)" d="M 119.945455 252
# L 130.090909 252
# L 130.090909 54.77551
# L 119.945455 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_9">
#     <path clip-path="url(#p4788fc0f1b)" d="M 130.090909 252
# L 140.236364 252
# L 140.236364 54.77551
# L 130.090909 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_10">
#     <path clip-path="url(#p4788fc0f1b)" d="M 140.236364 252
# L 150.381818 252
# L 150.381818 44.914286
# L 140.236364 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_11">
#     <path clip-path="url(#p4788fc0f1b)" d="M 150.381818 252
# L 160.527273 252
# L 160.527273 54.77551
# L 150.381818 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_12">
#     <path clip-path="url(#p4788fc0f1b)" d="M 160.527273 252
# L 170.672727 252
# L 170.672727 54.77551
# L 160.527273 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_13">
#     <path clip-path="url(#p4788fc0f1b)" d="M 170.672727 252
# L 180.818182 252
# L 180.818182 54.77551
# L 170.672727 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_14">
#     <path clip-path="url(#p4788fc0f1b)" d="M 180.818182 252
# L 190.963636 252
# L 190.963636 54.77551
# L 180.818182 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_15">
#     <path clip-path="url(#p4788fc0f1b)" d="M 190.963636 252
# L 201.109091 252
# L 201.109091 64.636735
# L 190.963636 64.636735
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_16">
#     <path clip-path="url(#p4788fc0f1b)" d="M 201.109091 252
# L 211.254545 252
# L 211.254545 54.77551
# L 201.109091 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_17">
#     <path clip-path="url(#p4788fc0f1b)" d="M 211.254545 252
# L 221.4 252
# L 221.4 54.77551
# L 211.254545 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_18">
#     <path clip-path="url(#p4788fc0f1b)" d="M 221.4 252
# L 231.545455 252
# L 231.545455 44.914286
# L 221.4 44.914286
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_19">
#     <path clip-path="url(#p4788fc0f1b)" d="M 231.545455 252
# L 241.690909 252
# L 241.690909 54.77551
# L 231.545455 54.77551
# z
# " style="fill:#0000ff;stroke:#000000;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch
path d="M 40.578125 39.3125
# Q 47.65625 37.796875 51.625 33
# Q 55.609375 28.21875 55.609375 21.1875
# Q 55.609375 10.40625 48.1875 4.484375
# Q 40.765625 -1.421875 27.09375 -1.421875
# Q 22.515625 -1.421875 17.65625 -0.515625
# Q 12.796875 0.390625 7.625 2.203125
# L 7.625 11.71875
# Q 11.71875 9.328125 16.59375 8.109375
# Q 21.484375 6.890625 26.8125 6.890625
# Q 36.078125 6.890625 40.9375 10.546875
# Q 45.796875 14.203125 45.796875 21.1875
# Q 45.796875 27.640625 41.28125 31.265625
# Q 36.765625 34.90625 28.71875 34.90625
# L 20.21875 34.90625
# L 20.21875 43.015625
# L 29.109375 43.015625
# Q 36.375 43.015625 40.234375 45.921875
# Q 44.09375 48.828125 44.09375 54.296875
# Q 44.09375 59.90625 40.109375 62.90625
# Q 36.140625 65.921875 28.71875 65.921875
# Q 24.65625 65.921875 20.015625 65.03125
# Q 15.375 64.15625 9.8125 62.3125
# L 9.8125 71.09375
# Q 15.4375 72.65625 20.34375 73.4375
# Q 25.25 74.21875 29.59375 74.21875
# Q 40.828125 74.21875 47.359375 69.109375
# Q 53.90625 64.015625 53.90625 55.328125
# Q 53.90625 49.265625 50.4375 45.09375
# Q 46.96875 40.921875 40.578125 39.3125
# z
# " id="DejaVuSans-51"/>
#     </defs>
#     <g transform="translate(134.136701 61.659759)scale(0.06 -0.06)">
#      <use xlink:href="#DejaVuSans-80"/>
#      <use x="60.302734" xlink:href="#DejaVuSans-71"/>
#      <use x="137.792969" xlink:href="#DejaVuSans-45"/>
#      <use x="173.876953" xlink:href="#DejaVuSans-49"/>
#      <use x="237.5" xlink:href="#DejaVuSans-51"/>
#     </g>
#    </g>
#    <g id="text_2">
#     <!-- NC-17 -->
#     <defs>
#      <path d="M 9.8125 72.90625
# L 23.09375 72.90625
# L 55.421875 11.921875
# L 55.421875 72.90625
# L 64.984375 72.90625
# L 64.984375 0
# L 51.703125 0
# L 19.390625 60.984375
# L 19.390625 0
# L 9.8125 0
# z
# " id="DejaVuSans-78"/>
#      <path d="M 64.40625 67.28125
# L 64.40625 56.890625
# Q 59.421875 61.53125 53.78125 63.8125
# Q 48.140625 66.109375 41.796875 66.109375
# Q 29.296875 66.109375 22.65625 58.46875
# Q 16.015625 50.828125 16.015625 36.375
# Q 16.015625 21.96875 22.65625 14.328125
# Q 29.296875 6.6875 41.796875 6.6875
# Q 48.140625 6.6875 53.78125 8.984375
# Q 59.421875 11.28125 64.40625 15.921875
# L 64.40625 5.609375
# Q 59.234375 2.09375 53.4375 0.328125
# Q 47.65625 -1.421875 41.21875 -1.421875
# Q 24.65625 -1.421875 15.125 8.703125
# Q 5.609375 18.84375 5.609375 36.375
# Q 5.609375 53.953125 15.125 64.078125
# Q 24.65625 74.21875 41.21875 74.21875
# Q 47.75 74.21875 53.53125 72.484375
# Q 59.328125 70.75 64.40625 67.28125
# z
# " id="DejaVuSans-67"/>
#      <path d="M 8.203125 72.90625
# L 55.078125 72.90625
# L 55.078125 68.703125
# L 28.609375 0
# L 18.3125 0
# L 43.21875 64.59375
# L 8.203125 64.59375
# z
# " id="DejaVuSans-55"/>
#     </defs>
#     <g transform="translate(108.156652 194.559952)scale(0.06 -0.06)">
#      <use xlink:href="#DejaVuSans-78"/>
#      <use x="74.804688" xlink:href="#DejaVuSans-67"/>
#      <use x="144.628906" xlink:href="#DejaVuSans-45"/>
#      <use x="180.712891" xlink:href="#DejaVuSans-49"/>
#      <use x="244.335938" xlink:href="#DejaVuSans-55"/>
#     </g>
#    </g>
#    <g id="text_3">
#     <!-- R -->
#     <defs>
#      <path d="M 44.390625 34.1875
# Q 47.5625 33.109375 50.5625 29.59375
# Q 53.5625 26.078125 56.59375 19.921875
# L 66.609375 0
# L 56 0
# L 46.6875 18.703125
# Q 43.0625 26.03125 39.671875 28.421875
# Q 36.28125 30.8125 30.421875 30.8125
# L 19.671875 30.8125
# L 19.671875 0
# L 9.8125 0
# L 9.8125 72.90625
# L 32.078125 72.90625
# Q 44.578125 72.90625 50.734375 67.671875
# Q 56.890625 62.453125 56.890625 51.90625
# Q 56.890625 45.015625 53.6875 40.46875
# Q 50.484375 35.9375 44.390625 34.1875
# z
# M 19.671875 64.796875
# L 19.671875 38.921875
# L 32.078125 38.921875
# Q 39.203125 38.921875 42.84375 42.21875
# Q 46.484375 45.515625 46.484375 51.90625
# Q 46.484375 58.296875 42.84375 61.54
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 last_update
#             </div>
#             <div>
#                 timestamp without time zone
#             </div>
#         </span> <span style='width:60%;text-align:center'>2013-05-26 14:50:58.951000</span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">1</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">1000</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">mean</td>
#                     <td style="text-align:left">2013-05-26 14:50:58.951002</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">min</td>
#                     <td style="text-align:left">2013-05-26 14:50:58.951000</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">max</td>
#                     <td style="text-align:left">2013-05-26 14:50:58.951000</td>
#                 </tr></table> </span></div>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 special_features
#             </div>
#             <div>
#                 ARRAY
#             </div>
#         </span> <span style="width:60%"><table style="width:100%"><tr><td style="text-align:right">['Trailers', 'Commentaries', 'Behind the Scenes']</td><td style="text-align:left">7.9%</td></tr><tr><td style="text-align:right">['Trailers']</td><td style="text-align:left">7.2%</td></tr><tr><td style="text-align:right">['Trailers', 'Commentaries']</td><td style="text-align:left">7.2%</td></tr><tr><td style="text-align:right">['Trailers', 'Behind the Scenes']</td><td style="text-align:left">7.2%</td></tr><tr><td style="text-align:right">['Deleted Scenes', 'Behind the Scenes']</td><td style="text-align:left">7.1%</td></tr></table></span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">15</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">1000</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr></table> </span></div>
# <div style='display:flex;justify-content:space-around;border:1px solid black;width:100%'>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-right:1px solid black;
#         justify-content:center;
#         padding:5px;
#         width:20%'>
#             <div style='font-weight: bold'>
#                 fulltext
#             </div>
#             <div>
#                 tsvector
#             </div>
#         </span> <span style="width:60%"><table style="width:100%"><tr><td style="text-align:right">'baloon':19 'build':14 'dog':8,11 'groov':2 'husband':16 'must':13 'perfect':1 'thrill':4 'yarn':5</td><td style="text-align:left">0.1%</td></tr><tr><td style="text-align:right">'hamlet':1 'man':8,11 'must':13 'outback':19 'reflect':5 'robot':16 'sink':14 'touch':4 'wisdom':2</td><td style="text-align:left">0.1%</td></tr><tr><td style="text-align:right">'astronaut':8 'boat':11,16 'bore':4 'california':18 'drama':5 'express':1 'face':14 'lone':2 'must':13</td><td style="text-align:left">0.1%</td></tr><tr><td style="text-align:right">'australia':18 'boy':8,16 'chariot':2 'dog':11 'hook':1 'insight':4 'must':13 'redeem':14 'stori':5</td><td style="text-align:left">0.1%</td></tr><tr><td style="text-align:right">'baloon':19 'confront':14 'documentari':5 'feminist':8,11,16 'mile':2 'must':13 'spi':1 'thrill':4</td><td style="text-align:left">0.1%</td></tr></table></span>
#         <span style='
#         display:flex;
#         flex-direction:column;
#         border-left:1px solid black;
#         padding:5px;
#         width:20%'>
#             <table>
#                 <tr>
#                     <td style="text-align:right">nUnique</td>
#                     <td style="text-align:left">1000</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">len</td>
#                     <td style="text-align:left">1000</td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right">null</td>
#                     <td style="text-align:left">0</td>
#                 </tr></table> </span></div>
